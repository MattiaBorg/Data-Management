# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in c:\users\marco aondio\anaconda\lib\site-packages (1.6.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\users\marco aondio\anaconda\lib\site-packages (from nba_api) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\marco aondio\anaconda\lib\site-packages (from nba_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marco aondio\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marco aondio\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marco aondio\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marco aondio\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2024.8.30)

# %%
from nba_api.stats.endpoints import leaguegamelog, boxscoretraditionalv2
import pandas as pd
import os
import time

# Funzione per ottenere le partite con punteggi corretti
def get_season_games(season, season_type="Regular Season"):
    try:
        # Estrai il registro delle partite
        gamelog = leaguegamelog.LeagueGameLog(season=season, season_type_all_star=season_type)
        games = gamelog.get_data_frames()[0]

        # Filtra le colonne principali
        games = games[["GAME_ID", "GAME_DATE", "MATCHUP", "TEAM_ABBREVIATION", "PTS", "WL"]]

        # Identifica le squadre di casa e trasferta
        games["HOME_TEAM"] = games["MATCHUP"].apply(lambda x: x.split(" vs. ")[0] if "vs." in x else x.split(" @ ")[1])
        games["AWAY_TEAM"] = games["MATCHUP"].apply(lambda x: x.split(" vs. ")[1] if "vs." in x else x.split(" @ ")[0])

        # Assegna i punteggi
        games["HOME_SCORE"] = games.apply(lambda x: x["PTS"] if x["TEAM_ABBREVIATION"] == x["HOME_TEAM"] else None, axis=1)
        games["AWAY_SCORE"] = games.apply(lambda x: x["PTS"] if x["TEAM_ABBREVIATION"] == x["AWAY_TEAM"] else None, axis=1)

        # Raggruppa i dati per partita
        games = games.groupby("GAME_ID").agg({
            "GAME_DATE": "first",
            "HOME_TEAM": "first",
            "AWAY_TEAM": "first",
            "HOME_SCORE": "max",
            "AWAY_SCORE": "max"
        }).reset_index()

        return games
    except Exception as e:
        print(f"Errore durante l'estrazione delle partite per la stagione {season} ({season_type}): {e}")
        return pd.DataFrame()

# Stagione desiderata
season = "2023-24"

# Ottieni le partite della Regular Season con punteggi
regular_season_games = get_season_games(season, season_type="Regular Season")

# Ottieni le partite dei Playoffs con punteggi
playoff_games = get_season_games(season, season_type="Playoffs")

# Combina le partite Regular Season e Playoffs
all_games = pd.concat([regular_season_games, playoff_games], ignore_index=True)

# Mostra un'anteprima delle partite combinate
print(all_games.head(10))

# Salva l'elenco completo in un file CSV
all_games.to_csv("nba_2023_24_all_games.csv", index=False)
print("Elenco completo delle partite con punteggi salvato in 'nba_2023_24_all_games.csv'.")
# Out:
#       GAME_ID   GAME_DATE HOME_TEAM AWAY_TEAM  HOME_SCORE  AWAY_SCORE
# 0  0022300001  2023-11-03       IND       CLE       121.0       116.0
# 1  0022300002  2023-11-03       MIL       NYK       110.0       105.0
# 2  0022300003  2023-11-03       MIA       WAS       121.0       114.0
# 3  0022300004  2023-11-03       CHI       BKN       107.0       109.0
# 4  0022300005  2023-11-03       OKC       GSW       139.0       141.0
# 5  0022300006  2023-11-03       DEN       DAL       125.0       114.0
# 6  0022300007  2023-11-03       POR       MEM       115.0       113.0
# 7  0022300008  2023-11-10       DET       PHI       106.0       114.0
# 8  0022300009  2023-11-10       WAS       CHA       117.0       124.0
# 9  0022300010  2023-11-10       BOS       BKN       121.0       107.0
# Elenco completo delle partite con punteggi salvato in 'nba_2023_24_all_games.csv'.

# %%
# Funzione per calcolare TS% e TOV%
def calculate_advanced_metrics(stats):
    # Calcola il True Shooting Percentage (TS%)
    stats["TS%"] = stats["PTS"] / (2 * (stats["FGA"] + 0.44 * stats["FTA"]))
    
    # Calcola il Turnover Percentage (TOV%)
    stats["TOV%"] = stats["TO"] / (stats["FGA"] + (0.44 * stats["FTA"]) + stats["TO"])
    
    return stats

# Funzione per ripulire il minutaggio
def clean_minutes_string(minutes):
    try:
        if isinstance(minutes, str) and ":" in minutes:
            # Mantieni solo la parte prima del punto e unisci con i secondi dopo i due punti
            mins = minutes.split(".")[0]
            secs = minutes.split(":")[1]
            return f"{mins}:{secs}"
        else:
            return minutes
    except Exception as e:
        print(f"Errore durante la pulizia del minutaggio: {e}")
        return minutes

# Funzione per estrarre e salvare le statistiche di una singola partita
def process_game_stats(game_id, output_dir):
    try:
        # Estrai le statistiche della partita
        boxscore = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id)
        stats = boxscore.get_data_frames()[0]

        # Filtra le colonne necessarie
        stats = stats[["PLAYER_NAME", "MIN", "PTS", "REB", "AST", "STL", "BLK", "TO", "FGA", "FTA", "FG_PCT"]]
        stats.rename(columns={"PLAYER_NAME": "player", "MIN": "mp"}, inplace=True)

        # Ripulisci il minutaggio
        stats["mp"] = stats["mp"].apply(clean_minutes_string)

        # Calcola TS% e TOV%
        stats = calculate_advanced_metrics(stats)

        # Salva il file CSV
        file_name = f"{game_id}.csv"
        output_path = os.path.join(output_dir, file_name)
        stats.to_csv(output_path, index=False)
        print(f"Statistiche salvate in {output_path}.")
    except Exception as e:
        print(f"Errore durante l'elaborazione delle statistiche per GAME_ID {game_id}: {e}")

# Funzione per processare tutte le partite
def process_all_games(season, season_type="Regular Season", output_dir="games_csv"):
    # Crea la directory di output se non esiste
    os.makedirs(output_dir, exist_ok=True)

    # Ottieni tutti i GAME_ID della stagione
    try:
        gamelog = leaguegamelog.LeagueGameLog(season=season, season_type_all_star=season_type)
        game_ids = gamelog.get_data_frames()[0]["GAME_ID"].unique()
        print(f"Trovati {len(game_ids)} GAME_ID per la stagione {season} ({season_type}).")

        # Processa ogni partita
        for i, game_id in enumerate(game_ids):
            print(f"Elaborazione GAME_ID {game_id} ({i + 1}/{len(game_ids)})...")
            process_game_stats(game_id, output_dir)
            time.sleep(1)  # Ritardo per evitare blocchi API

    except Exception as e:
        print(f"Errore durante l'estrazione dei GAME_ID: {e}")

# Esegui il codice per Regular Season e Playoff
season = "2023-24"
process_all_games(season, season_type="Regular Season", output_dir="regular_season_games")
process_all_games(season, season_type="Playoffs", output_dir="playoff_games")
# Out:
# Trovati 1230 GAME_ID per la stagione 2023-24 (Regular Season).
# Elaborazione GAME_ID 0022300061 (1/1230)...
# Statistiche salvate in regular_season_games\0022300061.csv.
# Elaborazione GAME_ID 0022300062 (2/1230)...
# Statistiche salvate in regular_season_games\0022300062.csv.
# Elaborazione GAME_ID 0022300069 (3/1230)...
# Statistiche salvate in regular_season_games\0022300069.csv.
# Elaborazione GAME_ID 0022300065 (4/1230)...
# Statistiche salvate in regular_season_games\0022300065.csv.
# Elaborazione GAME_ID 0022300064 (5/1230)...
# Statistiche salvate in regular_season_games\0022300064.csv.
# Elaborazione GAME_ID 0022300063 (6/1230)...
# Statistiche salvate in regular_season_games\0022300063.csv.
# Elaborazione GAME_ID 0022300074 (7/1230)...
# Statistiche salvate in regular_season_games\0022300074.csv.
# Elaborazione GAME_ID 0022300072 (8/1230)...
# Statistiche salvate in regular_season_games\0022300072.csv.
# Elaborazione GAME_ID 0022300071 (9/1230)...
# Statistiche salvate in regular_season_games\0022300071.csv.
# Elaborazione GAME_ID 0022300073 (10/1230)...
# Statistiche salvate in regular_season_games\0022300073.csv.
# Elaborazione GAME_ID 0022300068 (11/1230)...
# Statistiche salvate in regular_season_games\0022300068.csv.
# Elaborazione GAME_ID 0022300067 (12/1230)...
# Statistiche salvate in regular_season_games\0022300067.csv.
# Elaborazione GAME_ID 0022300070 (13/1230)...
# Statistiche salvate in regular_season_games\0022300070.csv.
# Elaborazione GAME_ID 0022300066 (14/1230)...
# Statistiche salvate in regular_season_games\0022300066.csv.
# Elaborazione GAME_ID 0022300075 (15/1230)...
# Statistiche salvate in regular_season_games\0022300075.csv.
# Elaborazione GAME_ID 0022300076 (16/1230)...
# Statistiche salvate in regular_season_games\0022300076.csv.
# Elaborazione GAME_ID 0022300081 (17/1230)...
# Statistiche salvate in regular_season_games\0022300081.csv.
# Elaborazione GAME_ID 0022300077 (18/1230)...
# Statistiche salvate in regular_season_games\0022300077.csv.
# Elaborazione GAME_ID 0022300085 (19/1230)...
# Statistiche salvate in regular_season_games\0022300085.csv.
# Elaborazione GAME_ID 0022300080 (20/1230)...
# Statistiche salvate in regular_season_games\0022300080.csv.
# Elaborazione GAME_ID 0022300079 (21/1230)...
# Statistiche salvate in regular_season_games\0022300079.csv.
# Elaborazione GAME_ID 0022300087 (22/1230)...
# Statistiche salvate in regular_season_games\0022300087.csv.
# Elaborazione GAME_ID 0022300083 (23/1230)...
# Statistiche salvate in regular_season_games\0022300083.csv.
# Elaborazione GAME_ID 0022300084 (24/1230)...
# Statistiche salvate in regular_season_games\0022300084.csv.
# Elaborazione GAME_ID 0022300082 (25/1230)...
# Statistiche salvate in regular_season_games\0022300082.csv.
# Elaborazione GAME_ID 0022300086 (26/1230)...
# Statistiche salvate in regular_season_games\0022300086.csv.
# Elaborazione GAME_ID 0022300078 (27/1230)...
# Statistiche salvate in regular_season_games\0022300078.csv.
# Elaborazione GAME_ID 0022300094 (28/1230)...
# Statistiche salvate in regular_season_games\0022300094.csv.
# Elaborazione GAME_ID 0022300089 (29/1230)...
# Statistiche salvate in regular_season_games\0022300089.csv.
# Elaborazione GAME_ID 0022300091 (30/1230)...
# Statistiche salvate in regular_season_games\0022300091.csv.
# Elaborazione GAME_ID 0022300090 (31/1230)...
# Statistiche salvate in regular_season_games\0022300090.csv.
# Elaborazione GAME_ID 0022300093 (32/1230)...
# Statistiche salvate in regular_season_games\0022300093.csv.
# Elaborazione GAME_ID 0022300088 (33/1230)...
# Statistiche salvate in regular_season_games\0022300088.csv.
# Elaborazione GAME_ID 0022300092 (34/1230)...
# Statistiche salvate in regular_season_games\0022300092.csv.
# Elaborazione GAME_ID 0022300097 (35/1230)...
# Statistiche salvate in regular_season_games\0022300097.csv.
# Elaborazione GAME_ID 0022300099 (36/1230)...
# Statistiche salvate in regular_season_games\0022300099.csv.
# Elaborazione GAME_ID 0022300095 (37/1230)...
# Statistiche salvate in regular_season_games\0022300095.csv.
# Elaborazione GAME_ID 0022300100 (38/1230)...
# Statistiche salvate in regular_season_games\0022300100.csv.
# Elaborazione GAME_ID 0022300096 (39/1230)...
# Statistiche salvate in regular_season_games\0022300096.csv.
# Elaborazione GAME_ID 0022300098 (40/1230)...
# Statistiche salvate in regular_season_games\0022300098.csv.
# Elaborazione GAME_ID 0022300104 (41/1230)...
# Statistiche salvate in regular_season_games\0022300104.csv.
# Elaborazione GAME_ID 0022300111 (42/1230)...
# Statistiche salvate in regular_season_games\0022300111.csv.
# Elaborazione GAME_ID 0022300108 (43/1230)...
# Statistiche salvate in regular_season_games\0022300108.csv.
# Elaborazione GAME_ID 0022300106 (44/1230)...
# Statistiche salvate in regular_season_games\0022300106.csv.
# Elaborazione GAME_ID 0022300102 (45/1230)...
# Statistiche salvate in regular_season_games\0022300102.csv.
# Elaborazione GAME_ID 0022300101 (46/1230)...
# Statistiche salvate in regular_season_games\0022300101.csv.
# Elaborazione GAME_ID 0022300109 (47/1230)...
# Statistiche salvate in regular_season_games\0022300109.csv.
# Elaborazione GAME_ID 0022300103 (48/1230)...
# Statistiche salvate in regular_season_games\0022300103.csv.
# Elaborazione GAME_ID 0022300107 (49/1230)...
# Statistiche salvate in regular_season_games\0022300107.csv.
# Elaborazione GAME_ID 0022300105 (50/1230)...
# Statistiche salvate in regular_season_games\0022300105.csv.
# Elaborazione GAME_ID 0022300110 (51/1230)...
# Statistiche salvate in regular_season_games\0022300110.csv.
# Elaborazione GAME_ID 0022300113 (52/1230)...
# Statistiche salvate in regular_season_games\0022300113.csv.
# Elaborazione GAME_ID 0022300114 (53/1230)...
# Statistiche salvate in regular_season_games\0022300114.csv.
# Elaborazione GAME_ID 0022300112 (54/1230)...
# Statistiche salvate in regular_season_games\0022300112.csv.
# Elaborazione GAME_ID 0022300118 (55/1230)...
# Statistiche salvate in regular_season_games\0022300118.csv.
# Elaborazione GAME_ID 0022300120 (56/1230)...
# Statistiche salvate in regular_season_games\0022300120.csv.
# Elaborazione GAME_ID 0022300123 (57/1230)...
# Statistiche salvate in regular_season_games\0022300123.csv.
# Elaborazione GAME_ID 0022300116 (58/1230)...
# Statistiche salvate in regular_season_games\0022300116.csv.
# Elaborazione GAME_ID 0022300119 (59/1230)...
# Statistiche salvate in regular_season_games\0022300119.csv.
# Elaborazione GAME_ID 0022300125 (60/1230)...
# Statistiche salvate in regular_season_games\0022300125.csv.
# Elaborazione GAME_ID 0022300127 (61/1230)...
# Statistiche salvate in regular_season_games\0022300127.csv.
# Elaborazione GAME_ID 0022300121 (62/1230)...
# Statistiche salvate in regular_season_games\0022300121.csv.
# Elaborazione GAME_ID 0022300117 (63/1230)...
# Statistiche salvate in regular_season_games\0022300117.csv.
# Elaborazione GAME_ID 0022300126 (64/1230)...
# Statistiche salvate in regular_season_games\0022300126.csv.
# Elaborazione GAME_ID 0022300115 (65/1230)...
# Statistiche salvate in regular_season_games\0022300115.csv.
# Elaborazione GAME_ID 0022300124 (66/1230)...
# Statistiche salvate in regular_season_games\0022300124.csv.
# Elaborazione GAME_ID 0022300122 (67/1230)...
# Statistiche salvate in regular_season_games\0022300122.csv.
# Elaborazione GAME_ID 0022300129 (68/1230)...
# Statistiche salvate in regular_season_games\0022300129.csv.
# Elaborazione GAME_ID 0022300130 (69/1230)...
# Statistiche salvate in regular_season_games\0022300130.csv.
# Elaborazione GAME_ID 0022300128 (70/1230)...
# Statistiche salvate in regular_season_games\0022300128.csv.
# Elaborazione GAME_ID 0022300131 (71/1230)...
# Statistiche salvate in regular_season_games\0022300131.csv.
# Elaborazione GAME_ID 0022300001 (72/1230)...
# Statistiche salvate in regular_season_games\0022300001.csv.
# Elaborazione GAME_ID 0022300007 (73/1230)...
# Statistiche salvate in regular_season_games\0022300007.csv.
# Elaborazione GAME_ID 0022300002 (74/1230)...
# Statistiche salvate in regular_season_games\0022300002.csv.
# Elaborazione GAME_ID 0022300003 (75/1230)...
# Statistiche salvate in regular_season_games\0022300003.csv.
# Elaborazione GAME_ID 0022300004 (76/1230)...
# Statistiche salvate in regular_season_games\0022300004.csv.
# Elaborazione GAME_ID 0022300005 (77/1230)...
# Statistiche salvate in regular_season_games\0022300005.csv.
# Elaborazione GAME_ID 0022300006 (78/1230)...
# Statistiche salvate in regular_season_games\0022300006.csv.
# Elaborazione GAME_ID 0022300138 (79/1230)...
# Statistiche salvate in regular_season_games\0022300138.csv.
# Elaborazione GAME_ID 0022300139 (80/1230)...
# Statistiche salvate in regular_season_games\0022300139.csv.
# Elaborazione GAME_ID 0022300137 (81/1230)...
# Statistiche salvate in regular_season_games\0022300137.csv.
# Elaborazione GAME_ID 0022300133 (82/1230)...
# Statistiche salvate in regular_season_games\0022300133.csv.
# Elaborazione GAME_ID 0022300134 (83/1230)...
# Statistiche salvate in regular_season_games\0022300134.csv.
# Elaborazione GAME_ID 0022300132 (84/1230)...
# Statistiche salvate in regular_season_games\0022300132.csv.
# Elaborazione GAME_ID 0022300136 (85/1230)...
# Statistiche salvate in regular_season_games\0022300136.csv.
# Elaborazione GAME_ID 0022300135 (86/1230)...
# Statistiche salvate in regular_season_games\0022300135.csv.
# Elaborazione GAME_ID 0022300142 (87/1230)...
# Statistiche salvate in regular_season_games\0022300142.csv.
# Elaborazione GAME_ID 0022300140 (88/1230)...
# Statistiche salvate in regular_season_games\0022300140.csv.
# Elaborazione GAME_ID 0022300144 (89/1230)...
# Statistiche salvate in regular_season_games\0022300144.csv.
# Elaborazione GAME_ID 0022300143 (90/1230)...
# Statistiche salvate in regular_season_games\0022300143.csv.
# Elaborazione GAME_ID 0022300141 (91/1230)...
# Statistiche salvate in regular_season_games\0022300141.csv.
# Elaborazione GAME_ID 0022300147 (92/1230)...
# Statistiche salvate in regular_season_games\0022300147.csv.
# Elaborazione GAME_ID 0022300152 (93/1230)...
# Statistiche salvate in regular_season_games\0022300152.csv.
# Elaborazione GAME_ID 0022300150 (94/1230)...
# Statistiche salvate in regular_season_games\0022300150.csv.
# Elaborazione GAME_ID 0022300151 (95/1230)...
# Statistiche salvate in regular_season_games\0022300151.csv.
# Elaborazione GAME_ID 0022300149 (96/1230)...
# Statistiche salvate in regular_season_games\0022300149.csv.
# Elaborazione GAME_ID 0022300155 (97/1230)...
# Statistiche salvate in regular_season_games\0022300155.csv.
# Elaborazione GAME_ID 0022300156 (98/1230)...
# Statistiche salvate in regular_season_games\0022300156.csv.
# Elaborazione GAME_ID 0022300146 (99/1230)...
# Statistiche salvate in regular_season_games\0022300146.csv.
# Elaborazione GAME_ID 0022300148 (100/1230)...
# Statistiche salvate in regular_season_games\0022300148.csv.
# Elaborazione GAME_ID 0022300145 (101/1230)...
# Statistiche salvate in regular_season_games\0022300145.csv.
# Elaborazione GAME_ID 0022300154 (102/1230)...
# Statistiche salvate in regular_season_games\0022300154.csv.
# Elaborazione GAME_ID 0022300153 (103/1230)...
# Statistiche salvate in regular_season_games\0022300153.csv.
# Elaborazione GAME_ID 0022300162 (104/1230)...
# Statistiche salvate in regular_season_games\0022300162.csv.
# Elaborazione GAME_ID 0022300170 (105/1230)...
# Statistiche salvate in regular_season_games\0022300170.csv.
# Elaborazione GAME_ID 0022300166 (106/1230)...
# Statistiche salvate in regular_season_games\0022300166.csv.
# Elaborazione GAME_ID 0022300161 (107/1230)...
# Statistiche salvate in regular_season_games\0022300161.csv.
# Elaborazione GAME_ID 0022300169 (108/1230)...
# Statistiche salvate in regular_season_games\0022300169.csv.
# Elaborazione GAME_ID 0022300159 (109/1230)...
# Statistiche salvate in regular_season_games\0022300159.csv.
# Elaborazione GAME_ID 0022300158 (110/1230)...
# Statistiche salvate in regular_season_games\0022300158.csv.
# Elaborazione GAME_ID 0022300163 (111/1230)...
# Statistiche salvate in regular_season_games\0022300163.csv.
# Elaborazione GAME_ID 0022300167 (112/1230)...
# Statistiche salvate in regular_season_games\0022300167.csv.
# Elaborazione GAME_ID 0022300165 (113/1230)...
# Statistiche salvate in regular_season_games\0022300165.csv.
# Elaborazione GAME_ID 0022300160 (114/1230)...
# Statistiche salvate in regular_season_games\0022300160.csv.
# Elaborazione GAME_ID 0022300164 (115/1230)...
# Statistiche salvate in regular_season_games\0022300164.csv.
# Elaborazione GAME_ID 0022300157 (116/1230)...
# Statistiche salvate in regular_season_games\0022300157.csv.
# Elaborazione GAME_ID 0022300168 (117/1230)...
# Statistiche salvate in regular_season_games\0022300168.csv.
# Elaborazione GAME_ID 0022300172 (118/1230)...
# Statistiche salvate in regular_season_games\0022300172.csv.
# Elaborazione GAME_ID 0022300171 (119/1230)...
# Statistiche salvate in regular_season_games\0022300171.csv.
# Elaborazione GAME_ID 0022300011 (120/1230)...
# Statistiche salvate in regular_season_games\0022300011.csv.
# Elaborazione GAME_ID 0022300010 (121/1230)...
# Statistiche salvate in regular_season_games\0022300010.csv.
# Elaborazione GAME_ID 0022300012 (122/1230)...
# Statistiche salvate in regular_season_games\0022300012.csv.
# Elaborazione GAME_ID 0022300016 (123/1230)...
# Statistiche salvate in regular_season_games\0022300016.csv.
# Elaborazione GAME_ID 0022300013 (124/1230)...
# Statistiche salvate in regular_season_games\0022300013.csv.
# Elaborazione GAME_ID 0022300008 (125/1230)...
# Statistiche salvate in regular_season_games\0022300008.csv.
# Elaborazione GAME_ID 0022300014 (126/1230)...
# Statistiche salvate in regular_season_games\0022300014.csv.
# Elaborazione GAME_ID 0022300015 (127/1230)...
# Statistiche salvate in regular_season_games\0022300015.csv.
# Elaborazione GAME_ID 0022300009 (128/1230)...
# Statistiche salvate in regular_season_games\0022300009.csv.
# Elaborazione GAME_ID 0022300176 (129/1230)...
# Statistiche salvate in regular_season_games\0022300176.csv.
# Elaborazione GAME_ID 0022300175 (130/1230)...
# Statistiche salvate in regular_season_games\0022300175.csv.
# Elaborazione GAME_ID 0022300174 (131/1230)...
# Statistiche salvate in regular_season_games\0022300174.csv.
# Elaborazione GAME_ID 0022300173 (132/1230)...
# Statistiche salvate in regular_season_games\0022300173.csv.
# Elaborazione GAME_ID 0022300187 (133/1230)...
# Statistiche salvate in regular_season_games\0022300187.csv.
# Elaborazione GAME_ID 0022300177 (134/1230)...
# Statistiche salvate in regular_season_games\0022300177.csv.
# Elaborazione GAME_ID 0022300178 (135/1230)...
# Statistiche salvate in regular_season_games\0022300178.csv.
# Elaborazione GAME_ID 0022300183 (136/1230)...
# Statistiche salvate in regular_season_games\0022300183.csv.
# Elaborazione GAME_ID 0022300179 (137/1230)...
# Statistiche salvate in regular_season_games\0022300179.csv.
# Elaborazione GAME_ID 0022300182 (138/1230)...
# Statistiche salvate in regular_season_games\0022300182.csv.
# Elaborazione GAME_ID 0022300186 (139/1230)...
# Statistiche salvate in regular_season_games\0022300186.csv.
# Elaborazione GAME_ID 0022300180 (140/1230)...
# Statistiche salvate in regular_season_games\0022300180.csv.
# Elaborazione GAME_ID 0022300184 (141/1230)...
# Statistiche salvate in regular_season_games\0022300184.csv.
# Elaborazione GAME_ID 0022300185 (142/1230)...
# Statistiche salvate in regular_season_games\0022300185.csv.
# Elaborazione GAME_ID 0022300181 (143/1230)...
# Statistiche salvate in regular_season_games\0022300181.csv.
# Elaborazione GAME_ID 0022300189 (144/1230)...
# Statistiche salvate in regular_season_games\0022300189.csv.
# Elaborazione GAME_ID 0022300190 (145/1230)...
# Statistiche salvate in regular_season_games\0022300190.csv.
# Elaborazione GAME_ID 0022300191 (146/1230)...
# Statistiche salvate in regular_season_games\0022300191.csv.
# Elaborazione GAME_ID 0022300188 (147/1230)...
# Statistiche salvate in regular_season_games\0022300188.csv.
# Elaborazione GAME_ID 0022300017 (148/1230)...
# Statistiche salvate in regular_season_games\0022300017.csv.
# Elaborazione GAME_ID 0022300026 (149/1230)...
# Statistiche salvate in regular_season_games\0022300026.csv.
# Elaborazione GAME_ID 0022300025 (150/1230)...
# Statistiche salvate in regular_season_games\0022300025.csv.
# Elaborazione GAME_ID 0022300020 (151/1230)...
# Statistiche salvate in regular_season_games\0022300020.csv.
# Elaborazione GAME_ID 0022300022 (152/1230)...
# Statistiche salvate in regular_season_games\0022300022.csv.
# Elaborazione GAME_ID 0022300019 (153/1230)...
# Statistiche salvate in regular_season_games\0022300019.csv.
# Elaborazione GAME_ID 0022300021 (154/1230)...
# Statistiche salvate in regular_season_games\0022300021.csv.
# Elaborazione GAME_ID 0022300018 (155/1230)...
# Statistiche salvate in regular_season_games\0022300018.csv.
# Elaborazione GAME_ID 0022300024 (156/1230)...
# Statistiche salvate in regular_season_games\0022300024.csv.
# Elaborazione GAME_ID 0022300023 (157/1230)...
# Statistiche salvate in regular_season_games\0022300023.csv.
# Elaborazione GAME_ID 0022300198 (158/1230)...
# Statistiche salvate in regular_season_games\0022300198.csv.
# Elaborazione GAME_ID 0022300192 (159/1230)...
# Statistiche salvate in regular_season_games\0022300192.csv.
# Elaborazione GAME_ID 0022300194 (160/1230)...
# Statistiche salvate in regular_season_games\0022300194.csv.
# Elaborazione GAME_ID 0022300193 (161/1230)...
# Statistiche salvate in regular_season_games\0022300193.csv.
# Elaborazione GAME_ID 0022300196 (162/1230)...
# Statistiche salvate in regular_season_games\0022300196.csv.
# Elaborazione GAME_ID 0022300197 (163/1230)...
# Statistiche salvate in regular_season_games\0022300197.csv.
# Elaborazione GAME_ID 0022300195 (164/1230)...
# Statistiche salvate in regular_season_games\0022300195.csv.
# Elaborazione GAME_ID 0022300199 (165/1230)...
# Statistiche salvate in regular_season_games\0022300199.csv.
# Elaborazione GAME_ID 0022300200 (166/1230)...
# Statistiche salvate in regular_season_games\0022300200.csv.
# Elaborazione GAME_ID 0022300201 (167/1230)...
# Statistiche salvate in regular_season_games\0022300201.csv.
# Elaborazione GAME_ID 0022300036 (168/1230)...
# Statistiche salvate in regular_season_games\0022300036.csv.
# Elaborazione GAME_ID 0022300031 (169/1230)...
# Statistiche salvate in regular_season_games\0022300031.csv.
# Elaborazione GAME_ID 0022300029 (170/1230)...
# Statistiche salvate in regular_season_games\0022300029.csv.
# Elaborazione GAME_ID 0022300035 (171/1230)...
# Statistiche salvate in regular_season_games\0022300035.csv.
# Elaborazione GAME_ID 0022300034 (172/1230)...
# Statistiche salvate in regular_season_games\0022300034.csv.
# Elaborazione GAME_ID 0022300032 (173/1230)...
# Statistiche salvate in regular_season_games\0022300032.csv.
# Elaborazione GAME_ID 0022300030 (174/1230)...
# Statistiche salvate in regular_season_games\0022300030.csv.
# Elaborazione GAME_ID 0022300028 (175/1230)...
# Statistiche salvate in regular_season_games\0022300028.csv.
# Elaborazione GAME_ID 0022300027 (176/1230)...
# Statistiche salvate in regular_season_games\0022300027.csv.
# Elaborazione GAME_ID 0022300037 (177/1230)...
# Statistiche salvate in regular_season_games\0022300037.csv.
# Elaborazione GAME_ID 0022300033 (178/1230)...
# Statistiche salvate in regular_season_games\0022300033.csv.
# Elaborazione GAME_ID 0022300205 (179/1230)...
# Statistiche salvate in regular_season_games\0022300205.csv.
# Elaborazione GAME_ID 0022300203 (180/1230)...
# Statistiche salvate in regular_season_games\0022300203.csv.
# Elaborazione GAME_ID 0022300204 (181/1230)...
# Statistiche salvate in regular_season_games\0022300204.csv.
# Elaborazione GAME_ID 0022300202 (182/1230)...
# Statistiche salvate in regular_season_games\0022300202.csv.
# Elaborazione GAME_ID 0022300207 (183/1230)...
# Statistiche salvate in regular_season_games\0022300207.csv.
# Elaborazione GAME_ID 0022300206 (184/1230)...
# Statistiche salvate in regular_season_games\0022300206.csv.
# Elaborazione GAME_ID 0022300210 (185/1230)...
# Statistiche salvate in regular_season_games\0022300210.csv.
# Elaborazione GAME_ID 0022300213 (186/1230)...
# Statistiche salvate in regular_season_games\0022300213.csv.
# Elaborazione GAME_ID 0022300212 (187/1230)...
# Statistiche salvate in regular_season_games\0022300212.csv.
# Elaborazione GAME_ID 0022300215 (188/1230)...
# Statistiche salvate in regular_season_games\0022300215.csv.
# Elaborazione GAME_ID 0022300211 (189/1230)...
# Statistiche salvate in regular_season_games\0022300211.csv.
# Elaborazione GAME_ID 0022300216 (190/1230)...
# Statistiche salvate in regular_season_games\0022300216.csv.
# Elaborazione GAME_ID 0022300208 (191/1230)...
# Statistiche salvate in regular_season_games\0022300208.csv.
# Elaborazione GAME_ID 0022300209 (192/1230)...
# Statistiche salvate in regular_season_games\0022300209.csv.
# Elaborazione GAME_ID 0022300214 (193/1230)...
# Statistiche salvate in regular_season_games\0022300214.csv.
# Elaborazione GAME_ID 0022300222 (194/1230)...
# Statistiche salvate in regular_season_games\0022300222.csv.
# Elaborazione GAME_ID 0022300221 (195/1230)...
# Statistiche salvate in regular_season_games\0022300221.csv.
# Elaborazione GAME_ID 0022300219 (196/1230)...
# Statistiche salvate in regular_season_games\0022300219.csv.
# Elaborazione GAME_ID 0022300223 (197/1230)...
# Statistiche salvate in regular_season_games\0022300223.csv.
# Elaborazione GAME_ID 0022300220 (198/1230)...
# Statistiche salvate in regular_season_games\0022300220.csv.
# Elaborazione GAME_ID 0022300224 (199/1230)...
# Statistiche salvate in regular_season_games\0022300224.csv.
# Elaborazione GAME_ID 0022300217 (200/1230)...
# Statistiche salvate in regular_season_games\0022300217.csv.
# Elaborazione GAME_ID 0022300218 (201/1230)...
# Statistiche salvate in regular_season_games\0022300218.csv.
# Elaborazione GAME_ID 0022300042 (202/1230)...
# Statistiche salvate in regular_season_games\0022300042.csv.
# Elaborazione GAME_ID 0022300038 (203/1230)...
# Statistiche salvate in regular_season_games\0022300038.csv.
# Elaborazione GAME_ID 0022300040 (204/1230)...
# Statistiche salvate in regular_season_games\0022300040.csv.
# Elaborazione GAME_ID 0022300041 (205/1230)...
# Statistiche salvate in regular_season_games\0022300041.csv.
# Elaborazione GAME_ID 0022300039 (206/1230)...
# Statistiche salvate in regular_season_games\0022300039.csv.
# Elaborazione GAME_ID 0022300229 (207/1230)...
# Statistiche salvate in regular_season_games\0022300229.csv.
# Elaborazione GAME_ID 0022300228 (208/1230)...
# Statistiche salvate in regular_season_games\0022300228.csv.
# Elaborazione GAME_ID 0022300225 (209/1230)...
# Statistiche salvate in regular_season_games\0022300225.csv.
# Elaborazione GAME_ID 0022300230 (210/1230)...
# Statistiche salvate in regular_season_games\0022300230.csv.
# Elaborazione GAME_ID 0022300226 (211/1230)...
# Statistiche salvate in regular_season_games\0022300226.csv.
# Elaborazione GAME_ID 0022300237 (212/1230)...
# Statistiche salvate in regular_season_games\0022300237.csv.
# Elaborazione GAME_ID 0022300238 (213/1230)...
# Statistiche salvate in regular_season_games\0022300238.csv.
# Elaborazione GAME_ID 0022300232 (214/1230)...
# Statistiche salvate in regular_season_games\0022300232.csv.
# Elaborazione GAME_ID 0022300231 (215/1230)...
# Statistiche salvate in regular_season_games\0022300231.csv.
# Elaborazione GAME_ID 0022300227 (216/1230)...
# Statistiche salvate in regular_season_games\0022300227.csv.
# Elaborazione GAME_ID 0022300233 (217/1230)...
# Statistiche salvate in regular_season_games\0022300233.csv.
# Elaborazione GAME_ID 0022300234 (218/1230)...
# Statistiche salvate in regular_season_games\0022300234.csv.
# Elaborazione GAME_ID 0022300235 (219/1230)...
# Statistiche salvate in regular_season_games\0022300235.csv.
# Elaborazione GAME_ID 0022300236 (220/1230)...
# Statistiche salvate in regular_season_games\0022300236.csv.
# Elaborazione GAME_ID 0022300049 (221/1230)...
# Statistiche salvate in regular_season_games\0022300049.csv.
# Elaborazione GAME_ID 0022300050 (222/1230)...
# Statistiche salvate in regular_season_games\0022300050.csv.
# Elaborazione GAME_ID 0022300051 (223/1230)...
# Statistiche salvate in regular_season_games\0022300051.csv.
# Elaborazione GAME_ID 0022300046 (224/1230)...
# Statistiche salvate in regular_season_games\0022300046.csv.
# Elaborazione GAME_ID 0022300044 (225/1230)...
# Statistiche salvate in regular_season_games\0022300044.csv.
# Elaborazione GAME_ID 0022300047 (226/1230)...
# Statistiche salvate in regular_season_games\0022300047.csv.
# Elaborazione GAME_ID 0022300052 (227/1230)...
# Statistiche salvate in regular_season_games\0022300052.csv.
# Elaborazione GAME_ID 0022300048 (228/1230)...
# Statistiche salvate in regular_season_games\0022300048.csv.
# Elaborazione GAME_ID 0022300045 (229/1230)...
# Statistiche salvate in regular_season_games\0022300045.csv.
# Elaborazione GAME_ID 0022300043 (230/1230)...
# Statistiche salvate in regular_season_games\0022300043.csv.
# Elaborazione GAME_ID 0022300241 (231/1230)...
# Statistiche salvate in regular_season_games\0022300241.csv.
# Elaborazione GAME_ID 0022300244 (232/1230)...
# Statistiche salvate in regular_season_games\0022300244.csv.
# Elaborazione GAME_ID 0022300240 (233/1230)...
# Statistiche salvate in regular_season_games\0022300240.csv.
# Elaborazione GAME_ID 0022300239 (234/1230)...
# Statistiche salvate in regular_season_games\0022300239.csv.
# Elaborazione GAME_ID 0022300242 (235/1230)...
# Statistiche salvate in regular_season_games\0022300242.csv.
# Elaborazione GAME_ID 0022300243 (236/1230)...
# Statistiche salvate in regular_season_games\0022300243.csv.
# Elaborazione GAME_ID 0022300252 (237/1230)...
# Statistiche salvate in regular_season_games\0022300252.csv.
# Elaborazione GAME_ID 0022300248 (238/1230)...
# Statistiche salvate in regular_season_games\0022300248.csv.
# Elaborazione GAME_ID 0022300245 (239/1230)...
# Statistiche salvate in regular_season_games\0022300245.csv.
# Elaborazione GAME_ID 0022300249 (240/1230)...
# Statistiche salvate in regular_season_games\0022300249.csv.
# Elaborazione GAME_ID 0022300247 (241/1230)...
# Statistiche salvate in regular_season_games\0022300247.csv.
# Elaborazione GAME_ID 0022300251 (242/1230)...
# Statistiche salvate in regular_season_games\0022300251.csv.
# Elaborazione GAME_ID 0022300250 (243/1230)...
# Statistiche salvate in regular_season_games\0022300250.csv.
# Elaborazione GAME_ID 0022300246 (244/1230)...
# Statistiche salvate in regular_season_games\0022300246.csv.
# Elaborazione GAME_ID 0022300254 (245/1230)...
# Statistiche salvate in regular_season_games\0022300254.csv.
# Elaborazione GAME_ID 0022300255 (246/1230)...
# Statistiche salvate in regular_season_games\0022300255.csv.
# Elaborazione GAME_ID 0022300253 (247/1230)...
# Statistiche salvate in regular_season_games\0022300253.csv.
# Elaborazione GAME_ID 0022300257 (248/1230)...
# Statistiche salvate in regular_season_games\0022300257.csv.
# Elaborazione GAME_ID 0022300256 (249/1230)...
# Statistiche salvate in regular_season_games\0022300256.csv.
# Elaborazione GAME_ID 0022300059 (250/1230)...
# Statistiche salvate in regular_season_games\0022300059.csv.
# Elaborazione GAME_ID 0022300056 (251/1230)...
# Statistiche salvate in regular_season_games\0022300056.csv.
# Elaborazione GAME_ID 0022300053 (252/1230)...
# Statistiche salvate in regular_season_games\0022300053.csv.
# Elaborazione GAME_ID 0022300057 (253/1230)...
# Statistiche salvate in regular_season_games\0022300057.csv.
# Elaborazione GAME_ID 0022300055 (254/1230)...
# Statistiche salvate in regular_season_games\0022300055.csv.
# Elaborazione GAME_ID 0022300060 (255/1230)...
# Statistiche salvate in regular_season_games\0022300060.csv.
# Elaborazione GAME_ID 0022300058 (256/1230)...
# Statistiche salvate in regular_season_games\0022300058.csv.
# Elaborazione GAME_ID 0022300054 (257/1230)...
# Statistiche salvate in regular_season_games\0022300054.csv.
# Elaborazione GAME_ID 0022300262 (258/1230)...
# Statistiche salvate in regular_season_games\0022300262.csv.
# Elaborazione GAME_ID 0022300261 (259/1230)...
# Statistiche salvate in regular_season_games\0022300261.csv.
# Elaborazione GAME_ID 0022300258 (260/1230)...
# Statistiche salvate in regular_season_games\0022300258.csv.
# Elaborazione GAME_ID 0022300259 (261/1230)...
# Statistiche salvate in regular_season_games\0022300259.csv.
# Elaborazione GAME_ID 0022300264 (262/1230)...
# Statistiche salvate in regular_season_games\0022300264.csv.
# Elaborazione GAME_ID 0022300260 (263/1230)...
# Statistiche salvate in regular_season_games\0022300260.csv.
# Elaborazione GAME_ID 0022300263 (264/1230)...
# Statistiche salvate in regular_season_games\0022300263.csv.
# Elaborazione GAME_ID 0022300272 (265/1230)...
# Statistiche salvate in regular_season_games\0022300272.csv.
# Elaborazione GAME_ID 0022300271 (266/1230)...
# Statistiche salvate in regular_season_games\0022300271.csv.
# Elaborazione GAME_ID 0022300267 (267/1230)...
# Statistiche salvate in regular_season_games\0022300267.csv.
# Elaborazione GAME_ID 0022300270 (268/1230)...
# Statistiche salvate in regular_season_games\0022300270.csv.
# Elaborazione GAME_ID 0022300273 (269/1230)...
# Statistiche salvate in regular_season_games\0022300273.csv.
# Elaborazione GAME_ID 0022300268 (270/1230)...
# Statistiche salvate in regular_season_games\0022300268.csv.
# Elaborazione GAME_ID 0022300265 (271/1230)...
# Statistiche salvate in regular_season_games\0022300265.csv.
# Elaborazione GAME_ID 0022300266 (272/1230)...
# Statistiche salvate in regular_season_games\0022300266.csv.
# Elaborazione GAME_ID 0022300269 (273/1230)...
# Statistiche salvate in regular_season_games\0022300269.csv.
# Elaborazione GAME_ID 0022300276 (274/1230)...
# Statistiche salvate in regular_season_games\0022300276.csv.
# Elaborazione GAME_ID 0022300275 (275/1230)...
# Statistiche salvate in regular_season_games\0022300275.csv.
# Elaborazione GAME_ID 0022300277 (276/1230)...
# Statistiche salvate in regular_season_games\0022300277.csv.
# Elaborazione GAME_ID 0022300279 (277/1230)...
# Statistiche salvate in regular_season_games\0022300279.csv.
# Elaborazione GAME_ID 0022300278 (278/1230)...
# Statistiche salvate in regular_season_games\0022300278.csv.
# Elaborazione GAME_ID 0022300274 (279/1230)...
# Statistiche salvate in regular_season_games\0022300274.csv.
# Elaborazione GAME_ID 0022300280 (280/1230)...
# Statistiche salvate in regular_season_games\0022300280.csv.
# Elaborazione GAME_ID 0022300282 (281/1230)...
# Statistiche salvate in regular_season_games\0022300282.csv.
# Elaborazione GAME_ID 0022300290 (282/1230)...
# Statistiche salvate in regular_season_games\0022300290.csv.
# Elaborazione GAME_ID 0022300291 (283/1230)...
# Statistiche salvate in regular_season_games\0022300291.csv.
# Elaborazione GAME_ID 0022300288 (284/1230)...
# Statistiche salvate in regular_season_games\0022300288.csv.
# Elaborazione GAME_ID 0022300283 (285/1230)...
# Statistiche salvate in regular_season_games\0022300283.csv.
# Elaborazione GAME_ID 0022300286 (286/1230)...
# Statistiche salvate in regular_season_games\0022300286.csv.
# Elaborazione GAME_ID 0022300284 (287/1230)...
# Statistiche salvate in regular_season_games\0022300284.csv.
# Elaborazione GAME_ID 0022300281 (288/1230)...
# Statistiche salvate in regular_season_games\0022300281.csv.
# Elaborazione GAME_ID 0022300285 (289/1230)...
# Statistiche salvate in regular_season_games\0022300285.csv.
# Elaborazione GAME_ID 0022300287 (290/1230)...
# Statistiche salvate in regular_season_games\0022300287.csv.
# Elaborazione GAME_ID 0022300289 (291/1230)...
# Statistiche salvate in regular_season_games\0022300289.csv.
# Elaborazione GAME_ID 0022301204 (292/1230)...
# Statistiche salvate in regular_season_games\0022301204.csv.
# Elaborazione GAME_ID 0022301202 (293/1230)...
# Statistiche salvate in regular_season_games\0022301202.csv.
# Elaborazione GAME_ID 0022301201 (294/1230)...
# Statistiche salvate in regular_season_games\0022301201.csv.
# Elaborazione GAME_ID 0022301203 (295/1230)...
# Statistiche salvate in regular_season_games\0022301203.csv.
# Elaborazione GAME_ID 0022301215 (296/1230)...
# Statistiche salvate in regular_season_games\0022301215.csv.
# Elaborazione GAME_ID 0022301214 (297/1230)...
# Statistiche salvate in regular_season_games\0022301214.csv.
# Elaborazione GAME_ID 0022301206 (298/1230)...
# Statistiche salvate in regular_season_games\0022301206.csv.
# Elaborazione GAME_ID 0022301211 (299/1230)...
# Statistiche salvate in regular_season_games\0022301211.csv.
# Elaborazione GAME_ID 0022301208 (300/1230)...
# Statistiche salvate in regular_season_games\0022301208.csv.
# Elaborazione GAME_ID 0022301212 (301/1230)...
# Statistiche salvate in regular_season_games\0022301212.csv.
# Elaborazione GAME_ID 0022301213 (302/1230)...
# Statistiche salvate in regular_season_games\0022301213.csv.
# Elaborazione GAME_ID 0022301207 (303/1230)...
# Statistiche salvate in regular_season_games\0022301207.csv.
# Elaborazione GAME_ID 0022301210 (304/1230)...
# Statistiche salvate in regular_season_games\0022301210.csv.
# Elaborazione GAME_ID 0022301205 (305/1230)...
# Statistiche salvate in regular_season_games\0022301205.csv.
# Elaborazione GAME_ID 0022301209 (306/1230)...
# Statistiche salvate in regular_season_games\0022301209.csv.
# Elaborazione GAME_ID 0022301229 (307/1230)...
# Statistiche salvate in regular_season_games\0022301229.csv.
# Elaborazione GAME_ID 0022301230 (308/1230)...
# Statistiche salvate in regular_season_games\0022301230.csv.
# Elaborazione GAME_ID 0022301227 (309/1230)...
# Statistiche salvate in regular_season_games\0022301227.csv.
# Elaborazione GAME_ID 0022301225 (310/1230)...
# Statistiche salvate in regular_season_games\0022301225.csv.
# Elaborazione GAME_ID 0022301226 (311/1230)...
# Statistiche salvate in regular_season_games\0022301226.csv.
# Elaborazione GAME_ID 0022301216 (312/1230)...
# Statistiche salvate in regular_season_games\0022301216.csv.
# Elaborazione GAME_ID 0022301217 (313/1230)...
# Statistiche salvate in regular_season_games\0022301217.csv.
# Elaborazione GAME_ID 0022301220 (314/1230)...
# Statistiche salvate in regular_season_games\0022301220.csv.
# Elaborazione GAME_ID 0022301228 (315/1230)...
# Statistiche salvate in regular_season_games\0022301228.csv.
# Elaborazione GAME_ID 0022301223 (316/1230)...
# Statistiche salvate in regular_season_games\0022301223.csv.
# Elaborazione GAME_ID 0022301222 (317/1230)...
# Statistiche salvate in regular_season_games\0022301222.csv.
# Elaborazione GAME_ID 0022301219 (318/1230)...
# Statistiche salvate in regular_season_games\0022301219.csv.
# Elaborazione GAME_ID 0022301221 (319/1230)...
# Statistiche salvate in regular_season_games\0022301221.csv.
# Elaborazione GAME_ID 0022301218 (320/1230)...
# Statistiche salvate in regular_season_games\0022301218.csv.
# Elaborazione GAME_ID 0022301224 (321/1230)...
# Statistiche salvate in regular_season_games\0022301224.csv.
# Elaborazione GAME_ID 0022300295 (322/1230)...
# Statistiche salvate in regular_season_games\0022300295.csv.
# Elaborazione GAME_ID 0022300296 (323/1230)...
# Statistiche salvate in regular_season_games\0022300296.csv.
# Elaborazione GAME_ID 0022300302 (324/1230)...
# Statistiche salvate in regular_season_games\0022300302.csv.
# Elaborazione GAME_ID 0022300298 (325/1230)...
# Statistiche salvate in regular_season_games\0022300298.csv.
# Elaborazione GAME_ID 0022300292 (326/1230)...
# Statistiche salvate in regular_season_games\0022300292.csv.
# Elaborazione GAME_ID 0022300294 (327/1230)...
# Statistiche salvate in regular_season_games\0022300294.csv.
# Elaborazione GAME_ID 0022300300 (328/1230)...
# Statistiche salvate in regular_season_games\0022300300.csv.
# Elaborazione GAME_ID 0022300299 (329/1230)...
# Statistiche salvate in regular_season_games\0022300299.csv.
# Elaborazione GAME_ID 0022300297 (330/1230)...
# Statistiche salvate in regular_season_games\0022300297.csv.
# Elaborazione GAME_ID 0022300303 (331/1230)...
# Statistiche salvate in regular_season_games\0022300303.csv.
# Elaborazione GAME_ID 0022300301 (332/1230)...
# Statistiche salvate in regular_season_games\0022300301.csv.
# Elaborazione GAME_ID 0022300304 (333/1230)...
# Statistiche salvate in regular_season_games\0022300304.csv.
# Elaborazione GAME_ID 0022300293 (334/1230)...
# Statistiche salvate in regular_season_games\0022300293.csv.
# Elaborazione GAME_ID 0022300305 (335/1230)...
# Statistiche salvate in regular_season_games\0022300305.csv.
# Elaborazione GAME_ID 0022300309 (336/1230)...
# Statistiche salvate in regular_season_games\0022300309.csv.
# Elaborazione GAME_ID 0022300306 (337/1230)...
# Statistiche salvate in regular_season_games\0022300306.csv.
# Elaborazione GAME_ID 0022300308 (338/1230)...
# Statistiche salvate in regular_season_games\0022300308.csv.
# Elaborazione GAME_ID 0022300307 (339/1230)...
# Statistiche salvate in regular_season_games\0022300307.csv.
# Elaborazione GAME_ID 0022300312 (340/1230)...
# Statistiche salvate in regular_season_games\0022300312.csv.
# Elaborazione GAME_ID 0022300313 (341/1230)...
# Statistiche salvate in regular_season_games\0022300313.csv.
# Elaborazione GAME_ID 0022300310 (342/1230)...
# Statistiche salvate in regular_season_games\0022300310.csv.
# Elaborazione GAME_ID 0022300311 (343/1230)...
# Statistiche salvate in regular_season_games\0022300311.csv.
# Elaborazione GAME_ID 0022300317 (344/1230)...
# Statistiche salvate in regular_season_games\0022300317.csv.
# Elaborazione GAME_ID 0022300318 (345/1230)...
# Statistiche salvate in regular_season_games\0022300318.csv.
# Elaborazione GAME_ID 0022300314 (346/1230)...
# Statistiche salvate in regular_season_games\0022300314.csv.
# Elaborazione GAME_ID 0022300316 (347/1230)...
# Statistiche salvate in regular_season_games\0022300316.csv.
# Elaborazione GAME_ID 0022300315 (348/1230)...
# Statistiche salvate in regular_season_games\0022300315.csv.
# Elaborazione GAME_ID 0022300320 (349/1230)...
# Statistiche salvate in regular_season_games\0022300320.csv.
# Elaborazione GAME_ID 0022300324 (350/1230)...
# Statistiche salvate in regular_season_games\0022300324.csv.
# Elaborazione GAME_ID 0022300319 (351/1230)...
# Statistiche salvate in regular_season_games\0022300319.csv.
# Elaborazione GAME_ID 0022300321 (352/1230)...
# Statistiche salvate in regular_season_games\0022300321.csv.
# Elaborazione GAME_ID 0022300323 (353/1230)...
# Statistiche salvate in regular_season_games\0022300323.csv.
# Elaborazione GAME_ID 0022300322 (354/1230)...
# Statistiche salvate in regular_season_games\0022300322.csv.
# Elaborazione GAME_ID 0022300325 (355/1230)...
# Statistiche salvate in regular_season_games\0022300325.csv.
# Elaborazione GAME_ID 0022300328 (356/1230)...
# Statistiche salvate in regular_season_games\0022300328.csv.
# Elaborazione GAME_ID 0022300333 (357/1230)...
# Statistiche salvate in regular_season_games\0022300333.csv.
# Elaborazione GAME_ID 0022300326 (358/1230)...
# Statistiche salvate in regular_season_games\0022300326.csv.
# Elaborazione GAME_ID 0022300332 (359/1230)...
# Statistiche salvate in regular_season_games\0022300332.csv.
# Elaborazione GAME_ID 0022300331 (360/1230)...
# Statistiche salvate in regular_season_games\0022300331.csv.
# Elaborazione GAME_ID 0022300329 (361/1230)...
# Statistiche salvate in regular_season_games\0022300329.csv.
# Elaborazione GAME_ID 0022300327 (362/1230)...
# Statistiche salvate in regular_season_games\0022300327.csv.
# Elaborazione GAME_ID 0022300330 (363/1230)...
# Statistiche salvate in regular_season_games\0022300330.csv.
# Elaborazione GAME_ID 0022300336 (364/1230)...
# Statistiche salvate in regular_season_games\0022300336.csv.
# Elaborazione GAME_ID 0022300338 (365/1230)...
# Statistiche salvate in regular_season_games\0022300338.csv.
# Elaborazione GAME_ID 0022300334 (366/1230)...
# Statistiche salvate in regular_season_games\0022300334.csv.
# Elaborazione GAME_ID 0022300337 (367/1230)...
# Statistiche salvate in regular_season_games\0022300337.csv.
# Elaborazione GAME_ID 0022300340 (368/1230)...
# Statistiche salvate in regular_season_games\0022300340.csv.
# Elaborazione GAME_ID 0022300342 (369/1230)...
# Statistiche salvate in regular_season_games\0022300342.csv.
# Elaborazione GAME_ID 0022300339 (370/1230)...
# Statistiche salvate in regular_season_games\0022300339.csv.
# Elaborazione GAME_ID 0022300343 (371/1230)...
# Statistiche salvate in regular_season_games\0022300343.csv.
# Elaborazione GAME_ID 0022300341 (372/1230)...
# Statistiche salvate in regular_season_games\0022300341.csv.
# Elaborazione GAME_ID 0022300335 (373/1230)...
# Statistiche salvate in regular_season_games\0022300335.csv.
# Elaborazione GAME_ID 0022300345 (374/1230)...
# Statistiche salvate in regular_season_games\0022300345.csv.
# Elaborazione GAME_ID 0022300344 (375/1230)...
# Statistiche salvate in regular_season_games\0022300344.csv.
# Elaborazione GAME_ID 0022300348 (376/1230)...
# Statistiche salvate in regular_season_games\0022300348.csv.
# Elaborazione GAME_ID 0022300347 (377/1230)...
# Statistiche salvate in regular_season_games\0022300347.csv.
# Elaborazione GAME_ID 0022300346 (378/1230)...
# Statistiche salvate in regular_season_games\0022300346.csv.
# Elaborazione GAME_ID 0022300359 (379/1230)...
# Statistiche salvate in regular_season_games\0022300359.csv.
# Elaborazione GAME_ID 0022300358 (380/1230)...
# Statistiche salvate in regular_season_games\0022300358.csv.
# Elaborazione GAME_ID 0022300356 (381/1230)...
# Statistiche salvate in regular_season_games\0022300356.csv.
# Elaborazione GAME_ID 0022300352 (382/1230)...
# Statistiche salvate in regular_season_games\0022300352.csv.
# Elaborazione GAME_ID 0022300354 (383/1230)...
# Statistiche salvate in regular_season_games\0022300354.csv.
# Elaborazione GAME_ID 0022300351 (384/1230)...
# Statistiche salvate in regular_season_games\0022300351.csv.
# Elaborazione GAME_ID 0022300349 (385/1230)...
# Statistiche salvate in regular_season_games\0022300349.csv.
# Elaborazione GAME_ID 0022300350 (386/1230)...
# Statistiche salvate in regular_season_games\0022300350.csv.
# Elaborazione GAME_ID 0022300353 (387/1230)...
# Statistiche salvate in regular_season_games\0022300353.csv.
# Elaborazione GAME_ID 0022300357 (388/1230)...
# Statistiche salvate in regular_season_games\0022300357.csv.
# Elaborazione GAME_ID 0022300355 (389/1230)...
# Statistiche salvate in regular_season_games\0022300355.csv.
# Elaborazione GAME_ID 0022300362 (390/1230)...
# Statistiche salvate in regular_season_games\0022300362.csv.
# Elaborazione GAME_ID 0022300363 (391/1230)...
# Statistiche salvate in regular_season_games\0022300363.csv.
# Elaborazione GAME_ID 0022300360 (392/1230)...
# Statistiche salvate in regular_season_games\0022300360.csv.
# Elaborazione GAME_ID 0022300361 (393/1230)...
# Statistiche salvate in regular_season_games\0022300361.csv.
# Elaborazione GAME_ID 0022300368 (394/1230)...
# Statistiche salvate in regular_season_games\0022300368.csv.
# Elaborazione GAME_ID 0022300369 (395/1230)...
# Statistiche salvate in regular_season_games\0022300369.csv.
# Elaborazione GAME_ID 0022300371 (396/1230)...
# Statistiche salvate in regular_season_games\0022300371.csv.
# Elaborazione GAME_ID 0022300372 (397/1230)...
# Statistiche salvate in regular_season_games\0022300372.csv.
# Elaborazione GAME_ID 0022300367 (398/1230)...
# Statistiche salvate in regular_season_games\0022300367.csv.
# Elaborazione GAME_ID 0022300366 (399/1230)...
# Statistiche salvate in regular_season_games\0022300366.csv.
# Elaborazione GAME_ID 0022300373 (400/1230)...
# Statistiche salvate in regular_season_games\0022300373.csv.
# Elaborazione GAME_ID 0022300370 (401/1230)...
# Statistiche salvate in regular_season_games\0022300370.csv.
# Elaborazione GAME_ID 0022300365 (402/1230)...
# Statistiche salvate in regular_season_games\0022300365.csv.
# Elaborazione GAME_ID 0022300364 (403/1230)...
# Statistiche salvate in regular_season_games\0022300364.csv.
# Elaborazione GAME_ID 0022300380 (404/1230)...
# Statistiche salvate in regular_season_games\0022300380.csv.
# Elaborazione GAME_ID 0022300376 (405/1230)...
# Statistiche salvate in regular_season_games\0022300376.csv.
# Elaborazione GAME_ID 0022300377 (406/1230)...
# Statistiche salvate in regular_season_games\0022300377.csv.
# Elaborazione GAME_ID 0022300378 (407/1230)...
# Statistiche salvate in regular_season_games\0022300378.csv.
# Elaborazione GAME_ID 0022300381 (408/1230)...
# Statistiche salvate in regular_season_games\0022300381.csv.
# Elaborazione GAME_ID 0022300374 (409/1230)...
# Statistiche salvate in regular_season_games\0022300374.csv.
# Elaborazione GAME_ID 0022300375 (410/1230)...
# Statistiche salvate in regular_season_games\0022300375.csv.
# Elaborazione GAME_ID 0022300379 (411/1230)...
# Statistiche salvate in regular_season_games\0022300379.csv.
# Elaborazione GAME_ID 0022300385 (412/1230)...
# Statistiche salvate in regular_season_games\0022300385.csv.
# Elaborazione GAME_ID 0022300383 (413/1230)...
# Statistiche salvate in regular_season_games\0022300383.csv.
# Elaborazione GAME_ID 0022300386 (414/1230)...
# Statistiche salvate in regular_season_games\0022300386.csv.
# Elaborazione GAME_ID 0022300384 (415/1230)...
# Statistiche salvate in regular_season_games\0022300384.csv.
# Elaborazione GAME_ID 0022300382 (416/1230)...
# Statistiche salvate in regular_season_games\0022300382.csv.
# Elaborazione GAME_ID 0022300387 (417/1230)...
# Statistiche salvate in regular_season_games\0022300387.csv.
# Elaborazione GAME_ID 0022300390 (418/1230)...
# Statistiche salvate in regular_season_games\0022300390.csv.
# Elaborazione GAME_ID 0022300397 (419/1230)...
# Statistiche salvate in regular_season_games\0022300397.csv.
# Elaborazione GAME_ID 0022300389 (420/1230)...
# Statistiche salvate in regular_season_games\0022300389.csv.
# Elaborazione GAME_ID 0022300394 (421/1230)...
# Statistiche salvate in regular_season_games\0022300394.csv.
# Elaborazione GAME_ID 0022300388 (422/1230)...
# Statistiche salvate in regular_season_games\0022300388.csv.
# Elaborazione GAME_ID 0022300398 (423/1230)...
# Statistiche salvate in regular_season_games\0022300398.csv.
# Elaborazione GAME_ID 0022300393 (424/1230)...
# Statistiche salvate in regular_season_games\0022300393.csv.
# Elaborazione GAME_ID 0022300395 (425/1230)...
# Statistiche salvate in regular_season_games\0022300395.csv.
# Elaborazione GAME_ID 0022300396 (426/1230)...
# Statistiche salvate in regular_season_games\0022300396.csv.
# Elaborazione GAME_ID 0022300399 (427/1230)...
# Statistiche salvate in regular_season_games\0022300399.csv.
# Elaborazione GAME_ID 0022300391 (428/1230)...
# Statistiche salvate in regular_season_games\0022300391.csv.
# Elaborazione GAME_ID 0022300392 (429/1230)...
# Statistiche salvate in regular_season_games\0022300392.csv.
# Elaborazione GAME_ID 0022300400 (430/1230)...
# Statistiche salvate in regular_season_games\0022300400.csv.
# Elaborazione GAME_ID 0022300401 (431/1230)...
# Statistiche salvate in regular_season_games\0022300401.csv.
# Elaborazione GAME_ID 0022300404 (432/1230)...
# Statistiche salvate in regular_season_games\0022300404.csv.
# Elaborazione GAME_ID 0022300405 (433/1230)...
# Statistiche salvate in regular_season_games\0022300405.csv.
# Elaborazione GAME_ID 0022300403 (434/1230)...
# Statistiche salvate in regular_season_games\0022300403.csv.
# Elaborazione GAME_ID 0022300402 (435/1230)...
# Statistiche salvate in regular_season_games\0022300402.csv.
# Elaborazione GAME_ID 0022300408 (436/1230)...
# Statistiche salvate in regular_season_games\0022300408.csv.
# Elaborazione GAME_ID 0022300409 (437/1230)...
# Statistiche salvate in regular_season_games\0022300409.csv.
# Elaborazione GAME_ID 0022300407 (438/1230)...
# Statistiche salvate in regular_season_games\0022300407.csv.
# Elaborazione GAME_ID 0022300414 (439/1230)...
# Statistiche salvate in regular_season_games\0022300414.csv.
# Elaborazione GAME_ID 0022300412 (440/1230)...
# Statistiche salvate in regular_season_games\0022300412.csv.
# Elaborazione GAME_ID 0022300410 (441/1230)...
# Statistiche salvate in regular_season_games\0022300410.csv.
# Elaborazione GAME_ID 0022300411 (442/1230)...
# Statistiche salvate in regular_season_games\0022300411.csv.
# Elaborazione GAME_ID 0022300413 (443/1230)...
# Statistiche salvate in regular_season_games\0022300413.csv.
# Elaborazione GAME_ID 0022300406 (444/1230)...
# Statistiche salvate in regular_season_games\0022300406.csv.
# Elaborazione GAME_ID 0022300416 (445/1230)...
# Statistiche salvate in regular_season_games\0022300416.csv.
# Elaborazione GAME_ID 0022300420 (446/1230)...
# Statistiche salvate in regular_season_games\0022300420.csv.
# Elaborazione GAME_ID 0022300419 (447/1230)...
# Statistiche salvate in regular_season_games\0022300419.csv.
# Elaborazione GAME_ID 0022300415 (448/1230)...
# Statistiche salvate in regular_season_games\0022300415.csv.
# Elaborazione GAME_ID 0022300418 (449/1230)...
# Statistiche salvate in regular_season_games\0022300418.csv.
# Elaborazione GAME_ID 0022300417 (450/1230)...
# Statistiche salvate in regular_season_games\0022300417.csv.
# Elaborazione GAME_ID 0022300425 (451/1230)...
# Statistiche salvate in regular_season_games\0022300425.csv.
# Elaborazione GAME_ID 0022300427 (452/1230)...
# Statistiche salvate in regular_season_games\0022300427.csv.
# Elaborazione GAME_ID 0022300422 (453/1230)...
# Statistiche salvate in regular_season_games\0022300422.csv.
# ...
# Elaborazione GAME_ID 0022301120 (1156/1230)...
# Statistiche salvate in regular_season_games\0022301120.csv.
# Elaborazione GAME_ID 0022301130 (1157/1230)...
# Statistiche salvate in regular_season_games\0022301130.csv.
# Elaborazione GAME_ID 0022301129 (1158/1230)...
# Statistiche salvate in regular_season_games\0022301129.csv.
# Elaborazione GAME_ID 0022301128 (1159/1230)...
# Statistiche salvate in regular_season_games\0022301128.csv.
# Elaborazione GAME_ID 0022301127 (1160/1230)...
# Statistiche salvate in regular_season_games\0022301127.csv.
# Elaborazione GAME_ID 0022301137 (1161/1230)...
# Statistiche salvate in regular_season_games\0022301137.csv.
# Elaborazione GAME_ID 0022301133 (1162/1230)...
# Statistiche salvate in regular_season_games\0022301133.csv.
# Elaborazione GAME_ID 0022301139 (1163/1230)...
# Statistiche salvate in regular_season_games\0022301139.csv.
# Elaborazione GAME_ID 0022301135 (1164/1230)...
# Statistiche salvate in regular_season_games\0022301135.csv.
# Elaborazione GAME_ID 0022301143 (1165/1230)...
# Statistiche salvate in regular_season_games\0022301143.csv.
# Elaborazione GAME_ID 0022301138 (1166/1230)...
# Statistiche salvate in regular_season_games\0022301138.csv.
# Elaborazione GAME_ID 0022301141 (1167/1230)...
# Statistiche salvate in regular_season_games\0022301141.csv.
# Elaborazione GAME_ID 0022301131 (1168/1230)...
# Statistiche salvate in regular_season_games\0022301131.csv.
# Elaborazione GAME_ID 0022301132 (1169/1230)...
# Statistiche salvate in regular_season_games\0022301132.csv.
# Elaborazione GAME_ID 0022301136 (1170/1230)...
# Statistiche salvate in regular_season_games\0022301136.csv.
# Elaborazione GAME_ID 0022301134 (1171/1230)...
# Statistiche salvate in regular_season_games\0022301134.csv.
# Elaborazione GAME_ID 0022301140 (1172/1230)...
# Statistiche salvate in regular_season_games\0022301140.csv.
# Elaborazione GAME_ID 0022301142 (1173/1230)...
# Statistiche salvate in regular_season_games\0022301142.csv.
# Elaborazione GAME_ID 0022301154 (1174/1230)...
# Statistiche salvate in regular_season_games\0022301154.csv.
# Elaborazione GAME_ID 0022301151 (1175/1230)...
# Statistiche salvate in regular_season_games\0022301151.csv.
# Elaborazione GAME_ID 0022301148 (1176/1230)...
# Statistiche salvate in regular_season_games\0022301148.csv.
# Elaborazione GAME_ID 0022301146 (1177/1230)...
# Statistiche salvate in regular_season_games\0022301146.csv.
# Elaborazione GAME_ID 0022301150 (1178/1230)...
# Statistiche salvate in regular_season_games\0022301150.csv.
# Elaborazione GAME_ID 0022301149 (1179/1230)...
# Statistiche salvate in regular_season_games\0022301149.csv.
# Elaborazione GAME_ID 0022301157 (1180/1230)...
# Statistiche salvate in regular_season_games\0022301157.csv.
# Elaborazione GAME_ID 0022301156 (1181/1230)...
# Statistiche salvate in regular_season_games\0022301156.csv.
# Elaborazione GAME_ID 0022301145 (1182/1230)...
# Statistiche salvate in regular_season_games\0022301145.csv.
# Elaborazione GAME_ID 0022301152 (1183/1230)...
# Statistiche salvate in regular_season_games\0022301152.csv.
# Elaborazione GAME_ID 0022301144 (1184/1230)...
# Statistiche salvate in regular_season_games\0022301144.csv.
# Elaborazione GAME_ID 0022301153 (1185/1230)...
# Statistiche salvate in regular_season_games\0022301153.csv.
# Elaborazione GAME_ID 0022301147 (1186/1230)...
# Statistiche salvate in regular_season_games\0022301147.csv.
# Elaborazione GAME_ID 0022301155 (1187/1230)...
# Statistiche salvate in regular_season_games\0022301155.csv.
# Elaborazione GAME_ID 0022301161 (1188/1230)...
# Statistiche salvate in regular_season_games\0022301161.csv.
# Elaborazione GAME_ID 0022301158 (1189/1230)...
# Statistiche salvate in regular_season_games\0022301158.csv.
# Elaborazione GAME_ID 0022301162 (1190/1230)...
# Statistiche salvate in regular_season_games\0022301162.csv.
# Elaborazione GAME_ID 0022301163 (1191/1230)...
# Statistiche salvate in regular_season_games\0022301163.csv.
# Elaborazione GAME_ID 0022301159 (1192/1230)...
# Statistiche salvate in regular_season_games\0022301159.csv.
# Elaborazione GAME_ID 0022301160 (1193/1230)...
# Statistiche salvate in regular_season_games\0022301160.csv.
# Elaborazione GAME_ID 0022301165 (1194/1230)...
# Statistiche salvate in regular_season_games\0022301165.csv.
# Elaborazione GAME_ID 0022301164 (1195/1230)...
# Statistiche salvate in regular_season_games\0022301164.csv.
# Elaborazione GAME_ID 0022301168 (1196/1230)...
# Statistiche salvate in regular_season_games\0022301168.csv.
# Elaborazione GAME_ID 0022301169 (1197/1230)...
# Statistiche salvate in regular_season_games\0022301169.csv.
# Elaborazione GAME_ID 0022301170 (1198/1230)...
# Statistiche salvate in regular_season_games\0022301170.csv.
# Elaborazione GAME_ID 0022301167 (1199/1230)...
# Statistiche salvate in regular_season_games\0022301167.csv.
# Elaborazione GAME_ID 0022301166 (1200/1230)...
# Statistiche salvate in regular_season_games\0022301166.csv.
# Elaborazione GAME_ID 0022301182 (1201/1230)...
# Statistiche salvate in regular_season_games\0022301182.csv.
# Elaborazione GAME_ID 0022301174 (1202/1230)...
# Statistiche salvate in regular_season_games\0022301174.csv.
# Elaborazione GAME_ID 0022301176 (1203/1230)...
# Statistiche salvate in regular_season_games\0022301176.csv.
# Elaborazione GAME_ID 0022301173 (1204/1230)...
# Statistiche salvate in regular_season_games\0022301173.csv.
# Elaborazione GAME_ID 0022301181 (1205/1230)...
# Statistiche salvate in regular_season_games\0022301181.csv.
# Elaborazione GAME_ID 0022301178 (1206/1230)...
# Statistiche salvate in regular_season_games\0022301178.csv.
# Elaborazione GAME_ID 0022301175 (1207/1230)...
# Statistiche salvate in regular_season_games\0022301175.csv.
# Elaborazione GAME_ID 0022301171 (1208/1230)...
# Statistiche salvate in regular_season_games\0022301171.csv.
# Elaborazione GAME_ID 0022301172 (1209/1230)...
# Statistiche salvate in regular_season_games\0022301172.csv.
# Elaborazione GAME_ID 0022301177 (1210/1230)...
# Statistiche salvate in regular_season_games\0022301177.csv.
# Elaborazione GAME_ID 0022301179 (1211/1230)...
# Statistiche salvate in regular_season_games\0022301179.csv.
# Elaborazione GAME_ID 0022301185 (1212/1230)...
# Statistiche salvate in regular_season_games\0022301185.csv.
# Elaborazione GAME_ID 0022301184 (1213/1230)...
# Statistiche salvate in regular_season_games\0022301184.csv.
# Elaborazione GAME_ID 0022301183 (1214/1230)...
# Statistiche salvate in regular_season_games\0022301183.csv.
# Elaborazione GAME_ID 0022301180 (1215/1230)...
# Statistiche salvate in regular_season_games\0022301180.csv.
# Elaborazione GAME_ID 0022301198 (1216/1230)...
# Statistiche salvate in regular_season_games\0022301198.csv.
# Elaborazione GAME_ID 0022301186 (1217/1230)...
# Statistiche salvate in regular_season_games\0022301186.csv.
# Elaborazione GAME_ID 0022301190 (1218/1230)...
# Statistiche salvate in regular_season_games\0022301190.csv.
# Elaborazione GAME_ID 0022301191 (1219/1230)...
# Statistiche salvate in regular_season_games\0022301191.csv.
# Elaborazione GAME_ID 0022301195 (1220/1230)...
# Statistiche salvate in regular_season_games\0022301195.csv.
# Elaborazione GAME_ID 0022301187 (1221/1230)...
# Statistiche salvate in regular_season_games\0022301187.csv.
# Elaborazione GAME_ID 0022301197 (1222/1230)...
# Statistiche salvate in regular_season_games\0022301197.csv.
# Elaborazione GAME_ID 0022301199 (1223/1230)...
# Statistiche salvate in regular_season_games\0022301199.csv.
# Elaborazione GAME_ID 0022301189 (1224/1230)...
# Statistiche salvate in regular_season_games\0022301189.csv.
# Elaborazione GAME_ID 0022301200 (1225/1230)...
# Statistiche salvate in regular_season_games\0022301200.csv.
# Elaborazione GAME_ID 0022301192 (1226/1230)...
# Statistiche salvate in regular_season_games\0022301192.csv.
# Elaborazione GAME_ID 0022301196 (1227/1230)...
# Statistiche salvate in regular_season_games\0022301196.csv.
# Elaborazione GAME_ID 0022301193 (1228/1230)...
# Statistiche salvate in regular_season_games\0022301193.csv.
# Elaborazione GAME_ID 0022301194 (1229/1230)...
# Statistiche salvate in regular_season_games\0022301194.csv.
# Elaborazione GAME_ID 0022301188 (1230/1230)...
# Statistiche salvate in regular_season_games\0022301188.csv.
# Trovati 82 GAME_ID per la stagione 2023-24 (Playoffs).
# Elaborazione GAME_ID 0042300151 (1/82)...
# Statistiche salvate in playoff_games\0042300151.csv.
# Elaborazione GAME_ID 0042300111 (2/82)...
# Statistiche salvate in playoff_games\0042300111.csv.
# Elaborazione GAME_ID 0042300131 (3/82)...
# Statistiche salvate in playoff_games\0042300131.csv.
# Elaborazione GAME_ID 0042300161 (4/82)...
# Statistiche salvate in playoff_games\0042300161.csv.
# Elaborazione GAME_ID 0042300141 (5/82)...
# Statistiche salvate in playoff_games\0042300141.csv.
# Elaborazione GAME_ID 0042300171 (6/82)...
# Statistiche salvate in playoff_games\0042300171.csv.
# Elaborazione GAME_ID 0042300121 (7/82)...
# Statistiche salvate in playoff_games\0042300121.csv.
# Elaborazione GAME_ID 0042300101 (8/82)...
# Statistiche salvate in playoff_games\0042300101.csv.
# Elaborazione GAME_ID 0042300152 (9/82)...
# Statistiche salvate in playoff_games\0042300152.csv.
# Elaborazione GAME_ID 0042300132 (10/82)...
# Statistiche salvate in playoff_games\0042300132.csv.
# Elaborazione GAME_ID 0042300112 (11/82)...
# Statistiche salvate in playoff_games\0042300112.csv.
# Elaborazione GAME_ID 0042300122 (12/82)...
# Statistiche salvate in playoff_games\0042300122.csv.
# Elaborazione GAME_ID 0042300172 (13/82)...
# Statistiche salvate in playoff_games\0042300172.csv.
# Elaborazione GAME_ID 0042300162 (14/82)...
# Statistiche salvate in playoff_games\0042300162.csv.
# Elaborazione GAME_ID 0042300102 (15/82)...
# Statistiche salvate in playoff_games\0042300102.csv.
# Elaborazione GAME_ID 0042300142 (16/82)...
# Statistiche salvate in playoff_games\0042300142.csv.
# Elaborazione GAME_ID 0042300113 (17/82)...
# Statistiche salvate in playoff_games\0042300113.csv.
# Elaborazione GAME_ID 0042300153 (18/82)...
# Statistiche salvate in playoff_games\0042300153.csv.
# Elaborazione GAME_ID 0042300133 (19/82)...
# Statistiche salvate in playoff_games\0042300133.csv.
# Elaborazione GAME_ID 0042300163 (20/82)...
# Statistiche salvate in playoff_games\0042300163.csv.
# Elaborazione GAME_ID 0042300173 (21/82)...
# Statistiche salvate in playoff_games\0042300173.csv.
# Elaborazione GAME_ID 0042300123 (22/82)...
# Statistiche salvate in playoff_games\0042300123.csv.
# Elaborazione GAME_ID 0042300154 (23/82)...
# Statistiche salvate in playoff_games\0042300154.csv.
# Elaborazione GAME_ID 0042300134 (24/82)...
# Statistiche salvate in playoff_games\0042300134.csv.
# Elaborazione GAME_ID 0042300143 (25/82)...
# Statistiche salvate in playoff_games\0042300143.csv.
# Elaborazione GAME_ID 0042300103 (26/82)...
# Statistiche salvate in playoff_games\0042300103.csv.
# Elaborazione GAME_ID 0042300114 (27/82)...
# Statistiche salvate in playoff_games\0042300114.csv.
# Elaborazione GAME_ID 0042300164 (28/82)...
# Statistiche salvate in playoff_games\0042300164.csv.
# Elaborazione GAME_ID 0042300124 (29/82)...
# Statistiche salvate in playoff_games\0042300124.csv.
# Elaborazione GAME_ID 0042300174 (30/82)...
# Statistiche salvate in playoff_games\0042300174.csv.
# Elaborazione GAME_ID 0042300144 (31/82)...
# Statistiche salvate in playoff_games\0042300144.csv.
# Elaborazione GAME_ID 0042300155 (32/82)...
# Statistiche salvate in playoff_games\0042300155.csv.
# Elaborazione GAME_ID 0042300104 (33/82)...
# Statistiche salvate in playoff_games\0042300104.csv.
# Elaborazione GAME_ID 0042300135 (34/82)...
# Statistiche salvate in playoff_games\0042300135.csv.
# Elaborazione GAME_ID 0042300115 (35/82)...
# Statistiche salvate in playoff_games\0042300115.csv.
# Elaborazione GAME_ID 0042300125 (36/82)...
# Statistiche salvate in playoff_games\0042300125.csv.
# Elaborazione GAME_ID 0042300105 (37/82)...
# Statistiche salvate in playoff_games\0042300105.csv.
# Elaborazione GAME_ID 0042300175 (38/82)...
# Statistiche salvate in playoff_games\0042300175.csv.
# Elaborazione GAME_ID 0042300116 (39/82)...
# Statistiche salvate in playoff_games\0042300116.csv.
# Elaborazione GAME_ID 0042300126 (40/82)...
# Statistiche salvate in playoff_games\0042300126.csv.
# Elaborazione GAME_ID 0042300176 (41/82)...
# Statistiche salvate in playoff_games\0042300176.csv.
# Elaborazione GAME_ID 0042300136 (42/82)...
# Statistiche salvate in playoff_games\0042300136.csv.
# Elaborazione GAME_ID 0042300231 (43/82)...
# Statistiche salvate in playoff_games\0042300231.csv.
# Elaborazione GAME_ID 0042300137 (44/82)...
# Statistiche salvate in playoff_games\0042300137.csv.
# Elaborazione GAME_ID 0042300211 (45/82)...
# Statistiche salvate in playoff_games\0042300211.csv.
# Elaborazione GAME_ID 0042300232 (46/82)...
# Statistiche salvate in playoff_games\0042300232.csv.
# Elaborazione GAME_ID 0042300221 (47/82)...
# Statistiche salvate in playoff_games\0042300221.csv.
# Elaborazione GAME_ID 0042300201 (48/82)...
# Statistiche salvate in playoff_games\0042300201.csv.
# Elaborazione GAME_ID 0042300212 (49/82)...
# Statistiche salvate in playoff_games\0042300212.csv.
# Elaborazione GAME_ID 0042300222 (50/82)...
# Statistiche salvate in playoff_games\0042300222.csv.
# Elaborazione GAME_ID 0042300202 (51/82)...
# Statistiche salvate in playoff_games\0042300202.csv.
# Elaborazione GAME_ID 0042300213 (52/82)...
# Statistiche salvate in playoff_games\0042300213.csv.
# Elaborazione GAME_ID 0042300233 (53/82)...
# Statistiche salvate in playoff_games\0042300233.csv.
# Elaborazione GAME_ID 0042300203 (54/82)...
# Statistiche salvate in playoff_games\0042300203.csv.
# Elaborazione GAME_ID 0042300223 (55/82)...
# Statistiche salvate in playoff_games\0042300223.csv.
# Elaborazione GAME_ID 0042300234 (56/82)...
# Statistiche salvate in playoff_games\0042300234.csv.
# Elaborazione GAME_ID 0042300214 (57/82)...
# Statistiche salvate in playoff_games\0042300214.csv.
# Elaborazione GAME_ID 0042300204 (58/82)...
# Statistiche salvate in playoff_games\0042300204.csv.
# Elaborazione GAME_ID 0042300224 (59/82)...
# Statistiche salvate in playoff_games\0042300224.csv.
# Elaborazione GAME_ID 0042300235 (60/82)...
# Statistiche salvate in playoff_games\0042300235.csv.
# Elaborazione GAME_ID 0042300215 (61/82)...
# Statistiche salvate in playoff_games\0042300215.csv.
# Elaborazione GAME_ID 0042300225 (62/82)...
# Statistiche salvate in playoff_games\0042300225.csv.
# Elaborazione GAME_ID 0042300205 (63/82)...
# Statistiche salvate in playoff_games\0042300205.csv.
# Elaborazione GAME_ID 0042300236 (64/82)...
# Statistiche salvate in playoff_games\0042300236.csv.
# Elaborazione GAME_ID 0042300216 (65/82)...
# Statistiche salvate in playoff_games\0042300216.csv.
# Elaborazione GAME_ID 0042300226 (66/82)...
# Statistiche salvate in playoff_games\0042300226.csv.
# Elaborazione GAME_ID 0042300237 (67/82)...
# Statistiche salvate in playoff_games\0042300237.csv.
# Elaborazione GAME_ID 0042300217 (68/82)...
# Statistiche salvate in playoff_games\0042300217.csv.
# Elaborazione GAME_ID 0042300301 (69/82)...
# Statistiche salvate in playoff_games\0042300301.csv.
# Elaborazione GAME_ID 0042300311 (70/82)...
# Statistiche salvate in playoff_games\0042300311.csv.
# Elaborazione GAME_ID 0042300302 (71/82)...
# Statistiche salvate in playoff_games\0042300302.csv.
# Elaborazione GAME_ID 0042300312 (72/82)...
# Statistiche salvate in playoff_games\0042300312.csv.
# Elaborazione GAME_ID 0042300303 (73/82)...
# Statistiche salvate in playoff_games\0042300303.csv.
# Elaborazione GAME_ID 0042300313 (74/82)...
# Statistiche salvate in playoff_games\0042300313.csv.
# Elaborazione GAME_ID 0042300304 (75/82)...
# Statistiche salvate in playoff_games\0042300304.csv.
# Elaborazione GAME_ID 0042300314 (76/82)...
# Statistiche salvate in playoff_games\0042300314.csv.
# Elaborazione GAME_ID 0042300315 (77/82)...
# Statistiche salvate in playoff_games\0042300315.csv.
# Elaborazione GAME_ID 0042300401 (78/82)...
# Statistiche salvate in playoff_games\0042300401.csv.
# Elaborazione GAME_ID 0042300402 (79/82)...
# Statistiche salvate in playoff_games\0042300402.csv.
# Elaborazione GAME_ID 0042300403 (80/82)...
# Statistiche salvate in playoff_games\0042300403.csv.
# Elaborazione GAME_ID 0042300404 (81/82)...
# Statistiche salvate in playoff_games\0042300404.csv.
# Elaborazione GAME_ID 0042300405 (82/82)...
# Statistiche salvate in playoff_games\0042300405.csv.

# %%
# Funzione per ottenere tutti i GAME_ID
def get_all_game_ids(season, season_type="Regular Season"):
    try:
        gamelog = leaguegamelog.LeagueGameLog(season=season, season_type_all_star=season_type)
        game_ids = gamelog.get_data_frames()[0]["GAME_ID"].unique()
        return game_ids
    except Exception as e:
        print(f"Errore durante l'estrazione dei GAME_ID: {e}")
        return []

# Estrai i GAME_ID per la Regular Season e i Playoff
season = "2023-24"
regular_season_game_ids = get_all_game_ids(season, "Regular Season")
playoff_game_ids = get_all_game_ids(season, "Playoffs")

# Confronto per Regular Season
regular_season_saved_files = [f.split(".")[0] for f in os.listdir("regular_season_games") if f.endswith(".csv")]
missing_regular_season_ids = [game_id for game_id in regular_season_game_ids if game_id not in regular_season_saved_files]
print(f"GAME_ID mancanti per la Regular Season: {missing_regular_season_ids}")

# Confronto per Playoff
playoff_saved_files = [f.split(".")[0] for f in os.listdir("playoff_games") if f.endswith(".csv")]
missing_playoff_ids = [game_id for game_id in playoff_game_ids if game_id not in playoff_saved_files]
print(f"GAME_ID mancanti per i Playoffs: {missing_playoff_ids}")

# Funzione per recuperare le partite mancanti
def process_missing_games(missing_game_ids, output_dir):
    for i, game_id in enumerate(missing_game_ids):
        print(f"Rielaborazione GAME_ID {game_id} ({i + 1}/{len(missing_game_ids)})...")
        try:
            process_game_stats(game_id, output_dir)  # Usa la funzione di elaborazione già definita
            time.sleep(1)  # Ritardo per evitare blocchi API
        except Exception as e:
            print(f"Errore durante la rielaborazione di GAME_ID {game_id}: {e}")

# Recupera i dati mancanti
process_missing_games(missing_regular_season_ids, "regular_season_games")
process_missing_games(missing_playoff_ids, "playoff_games")
# Out:
# GAME_ID mancanti per la Regular Season: []
# GAME_ID mancanti per i Playoffs: []
